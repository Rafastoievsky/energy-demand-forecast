# %% [markdown]
# ![spam](img/JB2.png)

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1.   Importing libraries and loading data

# %%
# Basic libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Normalization  libraries
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_percentage_error, r2_score

# Tensorflow with keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# Easy graphs with plotly
import plotly.express as px
import plotly.graph_objects as go

# Matplotlib plots look like
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (15,7)
import pickle as pk

import scipy
from scipy import stats

# %%
# Importing tensors
X_train = np.load('./outputs/split/X_train.npy')
X_val = np.load('./outputs/split/X_val.npy')
X_test = np.load('./outputs/split/X_test.npy')
y_train = np.load('./outputs/split/y_train.npy')
y_val = np.load('./outputs/split/y_val.npy')
y_test = np.load('./outputs/split/y_test.npy')

# %% [markdown]
# ## 2.   Setting the model

# %% [markdown]
# <summary>
#     <font size="4" color="orange"><b>1.1 Setting the parameters according to the tensors created in JNB1</b></font>
# </summary>

# %%
n_pasado = (24 * 7)+12
n_futuro = 24
n_salto = 12 

nom_attr = ['DEMANDA', 
            'MES', 
            'DIA', 
            'HORA',
            'PC1_TMAX',
            'PC1_TMIN',
            'PC1_PREC',
            'PC2_PREC',
            'LUNES_FESTIVO',
            'MARTES_POSTFESTIVO', 
            'SEMANA_SANTA', 
            '1_MAYO', 
            '10_MAYO', 
            '16_SEP',
            '2_NOV.', 
            'PRE-NAVIDAD_Y_NEW_YEAR', 
            'NAVIDAD_Y_NEW_YEAR',
            'POST-NAVIDAD_Y_NEW_YEAR' ]
n_attr = len(nom_attr)

# %% [markdown]
# <summary>
#     <font size="4" color="orange"><b>1.2 Configuring the LSTM Encoder-Decoder model</b></font>
# </summary>

# %% [markdown]
# MODEL
#
# <img src="img/encoders2_fig.png" alt="drawing" width="700"/>

# %% [markdown]
# LSTM UNIT
#
# <img src="img/lstm_unit.png" alt="drawing" width="400"/>
#
# Such that:
#
# * Forget Gate $F$: a NN with sigmoid
# * Candidate layer $C$: a NN with Tanh
# * Input Gate $I$: a NN with sigmoid
# * Output Gate $O$: a NN with sigmoid
# * Hidden state $h$: a vector, in our case we set $h\in\mathbb{R}^{100}$
# * Memory state $c$: a vector, in our case we set $c\in\mathbb{R}^{100}$

# %%
# Configuration of the encoder
encoder_inputs = layers.Input(shape=(n_pasado, n_attr))

encoder_l1 = layers.LSTM(100, return_state=True)# 100: dimension of hidden states
encoder_outputs1 = encoder_l1(encoder_inputs)

encoder_states1 = encoder_outputs1[1:]
# Out:
# Metal device set to: Apple M1 Max
# 2022-05-19 12:13:20.143304: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-05-19 12:13:20.143641: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
# Configuration of the encoder
decoder_rvec = layers.RepeatVector(n_futuro) # repeat vector 24 times
decoder_inputs = decoder_rvec(encoder_outputs1[0])

decoder_l1 = layers.LSTM(100, return_sequences=True)
decoder_l1_output = decoder_l1(decoder_inputs, initial_state=encoder_states1)

decoder_l2 = layers.TimeDistributed(layers.Dense(1)) # just one dense layer
decoder_outputs = decoder_l2(decoder_l1_output)

# %%
modelo = keras.models.Model(encoder_inputs, decoder_outputs)
modelo.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 180, 18)]    0           []
#
#  lstm (LSTM)                    [(None, 100),        47600       ['input_1[0][0]']
#                                  (None, 100),
#                                  (None, 100)]
#
#  repeat_vector (RepeatVector)   (None, 24, 100)      0           ['lstm[0][0]']
#
#  lstm_1 (LSTM)                  (None, 24, 100)      80400       ['repeat_vector[0][0]',
#                                                                   'lstm[0][1]',
#                                                                   'lstm[0][2]']
#
#  time_distributed (TimeDistribu  (None, 24, 1)       101         ['lstm_1[0][0]']
#  ted)
#
# ==================================================================================================
# Total params: 128,101
# Trainable params: 128,101
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## 3.   Training the model

# %% [markdown]
# Let $F_\theta: {\rm Mat}_{180\times 18}(\mathbb{R})\rightarrow \mathbb{R}^{24}$ be the nonlinear mapping given by the LSTM model where $\theta \in\mathbb{R}^{128,101}$ is the vector of parameters to fit
#
# The *training*, *validation* and *test* sets are codificated by the tensors $X_{180\times 18\times m}$ and $Y_{24\times 1\times m}$ for $m = m_{\rm train}, m_{\rm val}, m_{\rm test}$, as above. This tensors are, in each case,  just $m$ samples of the ordered pairs in ${\rm Mat}_{180\times 18}(\mathbb{R})\times \mathbb{R}^{24}$: $$\{(X^1,Y^1),(X^2,Y^2)
# \dots(X^m,Y^m)\}.$$
#
#
#
# <summary>
#     <font size="3" color="palevioletred"><b>Loss function</b></font>
# </summary>
#
# For fixed $\theta$ and tensor pair $X$ and $Y$, we set the **loss function** in terms of the MAE metric with the $\ell_1$ norm:
#
# $${\rm Loss}(X) = \frac{1}{m}\sum_{k=1}^m{\|F_\theta(X^k)-Y^k\|_1}$$
#
#
#
# <summary>
#     <font size="3" color="palevioletred"><b>Hyperparameters</b></font>
# </summary>
#
# * **epochs** (upper bound) = 25: An epoch is when an entire training set is passed  through the NN only once.
#
# * **batch size** = 32: Total number of training examples present in a single batch.
#
# * **patience** = 5:  Number of epochs with no improvement after which training will be stopped, in our case with respect to ${\rm Loss}(X_{\rm val})$.
#
# * **learning rate** $\alpha_{\rm epoch} = 1\times 10^{-3} \times 0.9 ^{\rm epoch}$
#
# <summary>
#     <font size="3" color="palevioletred"><b>Training process</b></font>
# </summary>

# %% [markdown]
# <img src="img/minibatch.png" alt="drawing" width="550"/>

# %%
## Sets the function for the rate learning in such a way that earning rate is smaller en each epoch
reduce_lr = keras.callbacks.LearningRateScheduler(lambda x: 1e-3 * 0.90 ** x) 

## During the run, the models of "best" result are stored according to "val_loss"

path_checkpoint = "./outputs/h5/model_checkpoint.h5"
modelckpt_callback = keras.callbacks.ModelCheckpoint(
    monitor="val_loss",
    filepath=path_checkpoint,
    verbose=1,
    save_weights_only=True,
    save_best_only=True,
)

## Setting the number of epochs with no improvement after which training will be stopped, 
## with respect to "val_loss". This is to avoid overfitting.
es_callback = keras.callbacks.EarlyStopping(
    monitor="val_loss", 
    min_delta=0, 
    patience=5 ### probar con menos
    
)

modelo.compile(
    optimizer=keras.optimizers.Adam(),  ### un tipo de descenso de gradiente más eficiente 'momento-inercia'
    loss="mae", ### determinación de la función de costo
    metrics=['accuracy']
)

history = modelo.fit(
    X_train,
    y_train,
    epochs=25,
    validation_data=(X_val,y_val),
    batch_size=32,
    callbacks=[reduce_lr, es_callback]
) ### guardar este history para graficar
# Out:
# Epoch 1/25
# 2022-05-19 12:13:23.480317: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-05-19 12:13:24.694315: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-19 12:13:24.891439: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-19 12:13:25.122412: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-19 12:13:25.213225: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-19 12:13:25.316447: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 3829/3829 [==============================] - ETA: 0s - loss: 0.0425 - accuracy: 1.9592e-04
# 2022-05-19 12:15:56.399158: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-19 12:15:56.470518: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-19 12:15:56.678534: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 3829/3829 [==============================] - 155s 40ms/step - loss: 0.0425 - accuracy: 1.9592e-04 - val_loss: 0.0211 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 2/25
# 3829/3829 [==============================] - 154s 40ms/step - loss: 0.0307 - accuracy: 1.9592e-04 - val_loss: 0.0209 - val_accuracy: 0.0000e+00 - lr: 9.0000e-04
# Epoch 3/25
# 3829/3829 [==============================] - 158s 41ms/step - loss: 0.0283 - accuracy: 1.9592e-04 - val_loss: 0.0185 - val_accuracy: 0.0000e+00 - lr: 8.1000e-04
# Epoch 4/25
# 3829/3829 [==============================] - 159s 41ms/step - loss: 0.0264 - accuracy: 1.9592e-04 - val_loss: 0.0220 - val_accuracy: 0.0000e+00 - lr: 7.2900e-04
# Epoch 5/25
# 3829/3829 [==============================] - 161s 42ms/step - loss: 0.0252 - accuracy: 1.9592e-04 - val_loss: 0.0177 - val_accuracy: 0.0000e+00 - lr: 6.5610e-04
# Epoch 6/25
# 3829/3829 [==============================] - 161s 42ms/step - loss: 0.0243 - accuracy: 1.9592e-04 - val_loss: 0.0193 - val_accuracy: 0.0000e+00 - lr: 5.9049e-04
# Epoch 7/25
# 3829/3829 [==============================] - 162s 42ms/step - loss: 0.0235 - accuracy: 1.9592e-04 - val_loss: 0.0159 - val_accuracy: 0.0000e+00 - lr: 5.3144e-04
# Epoch 8/25
# 3829/3829 [==============================] - 167s 44ms/step - loss: 0.0227 - accuracy: 1.9592e-04 - val_loss: 0.0174 - val_accuracy: 0.0000e+00 - lr: 4.7830e-04
# Epoch 9/25
# 3829/3829 [==============================] - 170s 44ms/step - loss: 0.0219 - accuracy: 1.9592e-04 - val_loss: 0.0159 - val_accuracy: 0.0000e+00 - lr: 4.3047e-04
# Epoch 10/25
# 3829/3829 [==============================] - 173s 45ms/step - loss: 0.0212 - accuracy: 1.9592e-04 - val_loss: 0.0167 - val_accuracy: 0.0000e+00 - lr: 3.8742e-04
# Epoch 11/25
# 3829/3829 [==============================] - 169s 44ms/step - loss: 0.0204 - accuracy: 1.9592e-04 - val_loss: 0.0181 - val_accuracy: 0.0000e+00 - lr: 3.4868e-04
# Epoch 12/25
# 3829/3829 [==============================] - 167s 44ms/step - loss: 0.0197 - accuracy: 1.9592e-04 - val_loss: 0.0166 - val_accuracy: 0.0000e+00 - lr: 3.1381e-04
# Epoch 13/25
# 3829/3829 [==============================] - 169s 44ms/step - loss: 0.0189 - accuracy: 1.9592e-04 - val_loss: 0.0169 - val_accuracy: 0.0000e+00 - lr: 2.8243e-04
# Epoch 14/25
# 3829/3829 [==============================] - 168s 44ms/step - loss: 0.0182 - accuracy: 1.9592e-04 - val_loss: 0.0176 - val_accuracy: 0.0000e+00 - lr: 2.5419e-04

# %% [markdown]
# ## 4.   Model validation

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %%
# Model Loss Chart
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 2>()
#       1 # Model Loss Chart
# ----> 2 plt.plot(history.history['loss'])
#       3 plt.plot(history.history['val_loss'])
#       4 plt.title('model loss')
#
# NameError: name 'plt' is not defined

# %%
## 5.   Model test results

# %%
df_test = pd.read_csv('./outputs/PCA/pca_exogenas_test.csv')
del df_test["Unnamed: 0"]

# %%
y_est = modelo.predict(X_test)
y_test[:,:,0].ravel().shape, y_est[:,:,0].ravel().shape, df_test['FECHA-HORA'][n_pasado + n_salto:].shape
# Out:
# 2022-05-19 12:51:36.180026: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-19 12:51:36.242281: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-19 12:51:36.452492: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# ((8568,), (8568,), (8568,))

# %%
scalers = pk.load(open("./outputs/DataProcessing/scalers.pkl",'rb'))

# %%
scaler = scalers['DEMANDA']
yr = scaler.inverse_transform(y_test[:,:,0].ravel().reshape(-1, 1))
yh = scaler.inverse_transform(y_est[:,:,0].ravel().reshape(-1, 1))

# %%
df_est = pd.DataFrame({
    "REAL": yr.ravel(),
    "ESTIMADO": yh.ravel(),
    "FECHA-HORA": df_test["FECHA-HORA"][n_pasado + n_salto:]     
})

# %%
df_est['FECHA-HORA']= pd.to_datetime(df_est['FECHA-HORA'])
df_est["HORA"] = df_est['FECHA-HORA'].dt.hour

# %%
real=[]
estimada =[]

df_est_result = pd.DataFrame(columns=['FECHA-HORA',"MAPE"])

for i, row in df_est.iterrows():

    n = row['HORA']
    
    real.append(row['REAL'])
    estimada.append(row['ESTIMADO'])
    
   
    if n == 23:
        df_est_result = df_est_result.append(pd.DataFrame({"FECHA-HORA": row['FECHA-HORA'],
                                           "MAPE": (mean_absolute_percentage_error(real, estimada))*100, 
                                           "R2": stats.pearsonr(real, estimada)[0]}, 
                                            index=[0]), ignore_index=True)
        n=0
        
        real=[]
        estimada =[]
    n+=1

# %%
df_est_result
# Out:
#               FECHA-HORA      MAPE        R2
# 0    2021-05-08 23:00:00  1.995519  0.988332
# 1    2021-05-09 23:00:00  1.908812  0.984747
# 2    2021-05-10 23:00:00     2.993  0.974718
# 3    2021-05-11 23:00:00  3.808471  0.971964
# 4    2021-05-12 23:00:00  4.042373  0.995424
# ..                   ...       ...       ...
# 352  2022-04-25 23:00:00  4.347743  0.983688
# 353  2022-04-26 23:00:00  0.957289  0.997325
# 354  2022-04-27 23:00:00  1.041079  0.997628
# 355  2022-04-28 23:00:00   1.35948  0.993735
# 356  2022-04-29 23:00:00  5.426072  0.958572
#
# [357 rows x 3 columns]

# %%
df_est_result.to_csv('./outputs/Training_comparativos/corrida_original.csv')

# %% [markdown]
# ## Histogramas MAPES

# %%
fig = px.histogram(df_est_result, x="MAPE", nbins=10, title="Histograma MAPE Datos Originales")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 fig = px.histogram(df_est_result, x="MAPE", nbins=10, title="Histograma MAPE Datos Originales")
#       2 fig.show()
#
# NameError: name 'px' is not defined

# %%
fig = px.histogram(df_est_result, x="R2", nbins=10, title="Histograma R2 Datos Originales")
fig.show()
# Out:
# <div>                            <div id="db8af95b-127c-482c-ae78-654298c7aeb5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("db8af95b-127c-482c-ae78-654298c7aeb5")) {                    Plotly.newPlot(                        "db8af95b-127c-482c-ae78-654298c7aeb5",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"R2=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":10,"offsetgroup":"","orientation":"v","showlegend":false,"x":[0.9883320294030905,0.9847465039247174,0.9747178560010934,0.9719642141725154,0.9954242490922914,0.9952527887684368,0.997106883331025,0.9810919678503724,0.9881003400121413,0.97146225338299,0.9931368076785293,0.9911224108050991,0.99501322433783,0.975209087811597,0.9948850415665154,0.9937260122702997,0.9941489018017436,0.9978217912924214,0.9961911060430311,0.9971242907542188,0.9902709580650356,0.9968295276054701,0.9955459339859484,0.9860670838671276,0.9975914011539178,0.996183055886729,0.9988181326508758,0.9953423297095317,0.9973152219902359,0.9919187980702822,0.9975051557579266,0.9981306303850064,0.9953368952202826,0.9968708951189056,0.9911027415621908,0.990129164444211,0.9936067170141947,0.9953834922092349,0.9912756831910652,0.9871679101732567,0.9916509890871809,0.95348995177505,0.9581068576082524,0.9246782477024054,0.9968968055855338,0.9948389111250893,0.9777002168284944,0.99496925811273,0.991281580160277,0.9680705804018538,0.9670195647146735,0.9941890410096695,0.9471395937096461,0.9937353868673732,0.9816627806817713,0.9957643935649311,0.8517321699506363,0.9088647791040695,0.8816929401772959,0.9970517867543751,0.9734682026545406,0.9927185126334652,0.9924740799800872,0.993339704329028,0.9875342162559558,0.9919000477947021,0.9822813993688096,0.9974411336622716,0.9892849652507386,0.993592682920927,0.9843745970520172,0.9804528656232713,0.9833021983195301,0.9840108226136318,0.9646562956134335,0.9859272869112939,0.9962204132320162,0.9367934603270617,0.9932300759017044,0.9760472110615457,0.9966918180237,0.9909974057699562,0.9754818499916502,0.9744048673317884,0.9700330100120345,0.9709528428841917,0.9988944530158579,0.9506352081844106,0.973245452504672,0.9921933892818725,0.9904540903919278,0.9951464375290832,0.9514363100345515,0.9941111241015597,0.9704639260326567,0.99565184295147,0.8348084520667097,0.9783812195328404,0.9633558174396655,0.9882574772462982,0.9919515537183952,0.9844821972921232,0.9852785993786272,0.9971624482135877,0.9848229666083164,0.9765799150664267,0.9874439596949408,0.8634890404673955,0.9868469578657342,0.9946192011779464,0.9207661506719318,0.9285918808478829,0.9941928582192343,0.9505733102539353,0.9486294696273623,0.9510568011101015,0.9808430060195369,0.9936591113411651,0.9505285646566056,0.9010518039824982,0.9774984068332168,0.9832368885645556,0.9951748596863643,0.9850223069349668,0.9941396409631581,0.9969792417349808,0.988518957585571,0.9973299023779988,0.99729776272312,0.9872830645077555,0.9730324280214189,0.969768352947919,0.9870979988668386,0.9913197317401082,0.9738984293525721,0.9959195425150522,0.9685172597006866,0.9876031818275972,0.9622106757665941,0.988233203138116,0.8939428352546751,0.9796276683232985,0.9969960249207392,0.9923370353210174,0.9859617042018702,0.9933215767032657,0.9969999536672043,0.9902248587126262,0.9937155627155201,0.9982641250144448,0.9985692618577867,0.9986893664567031,0.9965802252145894,0.9880290489432829,0.9959073660912373,0.9977697153089224,0.9509132343615387,0.5170585356941746,0.8107271199518026,0.9857488427682278,0.992633522364866,0.996471517288838,0.9930473990551676,0.9953690093782125,0.9523066814816677,0.993817897266424,0.9962487067700476,0.9879454253997625,0.9820236116179982,0.9788973595575764,0.9890350803249347,0.98 ...

# %%
### Además de esto poner el histograma del df_est_result.MAPE y de df_est_result.R2

fig = px.line(df_est_result,x='FECHA-HORA', y='MAPE' ,title="MAPE Pronostico Redes Neuronales Encoders")
fig.show()
# Out:
# <div>                            <div id="a028b73e-feca-475f-bccd-d6e848bc5902" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a028b73e-feca-475f-bccd-d6e848bc5902")) {                    Plotly.newPlot(                        "a028b73e-feca-475f-bccd-d6e848bc5902",                        [{"hovertemplate":"FECHA-HORA=%{x}<br>MAPE=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2021-05-08T23:00:00","2021-05-09T23:00:00","2021-05-10T23:00:00","2021-05-11T23:00:00","2021-05-12T23:00:00","2021-05-13T23:00:00","2021-05-14T23:00:00","2021-05-15T23:00:00","2021-05-16T23:00:00","2021-05-17T23:00:00","2021-05-18T23:00:00","2021-05-19T23:00:00","2021-05-20T23:00:00","2021-05-21T23:00:00","2021-05-22T23:00:00","2021-05-23T23:00:00","2021-05-24T23:00:00","2021-05-25T23:00:00","2021-05-26T23:00:00","2021-05-27T23:00:00","2021-05-28T23:00:00","2021-05-29T23:00:00","2021-05-30T23:00:00","2021-05-31T23:00:00","2021-06-01T23:00:00","2021-06-02T23:00:00","2021-06-03T23:00:00","2021-06-04T23:00:00","2021-06-05T23:00:00","2021-06-06T23:00:00","2021-06-07T23:00:00","2021-06-08T23:00:00","2021-06-09T23:00:00","2021-06-10T23:00:00","2021-06-11T23:00:00","2021-06-12T23:00:00","2021-06-13T23:00:00","2021-06-14T23:00:00","2021-06-15T23:00:00","2021-06-16T23:00:00","2021-06-17T23:00:00","2021-06-18T23:00:00","2021-06-19T23:00:00","2021-06-20T23:00:00","2021-06-21T23:00:00","2021-06-22T23:00:00","2021-06-23T23:00:00","2021-06-24T23:00:00","2021-06-25T23:00:00","2021-06-26T23:00:00","2021-06-27T23:00:00","2021-06-28T23:00:00","2021-06-29T23:00:00","2021-06-30T23:00:00","2021-07-01T23:00:00","2021-07-02T23:00:00","2021-07-03T23:00:00","2021-07-04T23:00:00","2021-07-05T23:00:00","2021-07-06T23:00:00","2021-07-07T23:00:00","2021-07-08T23:00:00","2021-07-09T23:00:00","2021-07-10T23:00:00","2021-07-11T23:00:00","2021-07-12T23:00:00","2021-07-13T23:00:00","2021-07-14T23:00:00","2021-07-15T23:00:00","2021-07-16T23:00:00","2021-07-17T23:00:00","2021-07-18T23:00:00","2021-07-19T23:00:00","2021-07-20T23:00:00","2021-07-21T23:00:00","2021-07-22T23:00:00","2021-07-23T23:00:00","2021-07-24T23:00:00","2021-07-25T23:00:00","2021-07-26T23:00:00","2021-07-27T23:00:00","2021-07-28T23:00:00","2021-07-29T23:00:00","2021-07-30T23:00:00","2021-07-31T23:00:00","2021-08-01T23:00:00","2021-08-02T23:00:00","2021-08-03T23:00:00","2021-08-04T23:00:00","2021-08-05T23:00:00","2021-08-06T23:00:00","2021-08-07T23:00:00","2021-08-08T23:00:00","2021-08-09T23:00:00","2021-08-10T23:00:00","2021-08-11T23:00:00","2021-08-12T23:00:00","2021-08-13T23:00:00","2021-08-14T23:00:00","2021-08-15T23:00:00","2021-08-16T23:00:00","2021-08-17T23:00:00","2021-08-18T23:00:00","2021-08-19T23:00:00","2021-08-20T23:00:00","2021-08-21T23:00:00","2021-08-22T23:00:00","2021-08-23T23:00:00","2021-08-24T23:00:00","2021-08-25T23:00:00","2021-08-26T23:00:00","2021-08-27T23:00:00","2021-08-28T23:00:00","2021-08-29T23:00:00","2021-08-30T23:00:00","2021-08-31T23:00:00","2021-09-01T23:00:00","2021-09-02T23:00:00","2021-09-03T23:00:00","2021-09-04T23:00:00","2021-09-05T23:00:00","2021-09-06T23:00:00","2021-09-07T23:00:00","2021-09-08T23:00:00","2021-09-09T23:00:00","2021-09-10T23:00:00","2021-09-11T23:00:00","2021-09-12T23:00:00","2021-09-13T23:00:00","2021-09-14T23:00:00","2021-09-15T23:00:00","2021-09-16T23:00:00","2021-09-17T23:00:00","2021-09-18T23:00:00","2021-09-19T23:00:00","2021-09-20T23:00:00","2021-09-21T23:00:00","2021-09-22T23:00:00","2021-09-23T23:00:00","2021-09-24T23:00:00","2021-09-25T23:00:00","2021-09-26T23:00:00","2021-09-27T23:00:00","2021-09-28T23:00:00","2021-09-29T23:00:00","2021-09-30T23:00:00","2021-10-01T23:00:00","2021-10-02T23:00 ...

# %%
fig = px.line(df_est_result,x='FECHA-HORA', y='R2' ,title="R2 Score Pronostico Redes Neuronales Encoders")
fig.show()
# Out:
# <div>                            <div id="edd78cee-7e42-40ca-8429-97d2189b652a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("edd78cee-7e42-40ca-8429-97d2189b652a")) {                    Plotly.newPlot(                        "edd78cee-7e42-40ca-8429-97d2189b652a",                        [{"hovertemplate":"FECHA-HORA=%{x}<br>R2=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2021-05-08T23:00:00","2021-05-09T23:00:00","2021-05-10T23:00:00","2021-05-11T23:00:00","2021-05-12T23:00:00","2021-05-13T23:00:00","2021-05-14T23:00:00","2021-05-15T23:00:00","2021-05-16T23:00:00","2021-05-17T23:00:00","2021-05-18T23:00:00","2021-05-19T23:00:00","2021-05-20T23:00:00","2021-05-21T23:00:00","2021-05-22T23:00:00","2021-05-23T23:00:00","2021-05-24T23:00:00","2021-05-25T23:00:00","2021-05-26T23:00:00","2021-05-27T23:00:00","2021-05-28T23:00:00","2021-05-29T23:00:00","2021-05-30T23:00:00","2021-05-31T23:00:00","2021-06-01T23:00:00","2021-06-02T23:00:00","2021-06-03T23:00:00","2021-06-04T23:00:00","2021-06-05T23:00:00","2021-06-06T23:00:00","2021-06-07T23:00:00","2021-06-08T23:00:00","2021-06-09T23:00:00","2021-06-10T23:00:00","2021-06-11T23:00:00","2021-06-12T23:00:00","2021-06-13T23:00:00","2021-06-14T23:00:00","2021-06-15T23:00:00","2021-06-16T23:00:00","2021-06-17T23:00:00","2021-06-18T23:00:00","2021-06-19T23:00:00","2021-06-20T23:00:00","2021-06-21T23:00:00","2021-06-22T23:00:00","2021-06-23T23:00:00","2021-06-24T23:00:00","2021-06-25T23:00:00","2021-06-26T23:00:00","2021-06-27T23:00:00","2021-06-28T23:00:00","2021-06-29T23:00:00","2021-06-30T23:00:00","2021-07-01T23:00:00","2021-07-02T23:00:00","2021-07-03T23:00:00","2021-07-04T23:00:00","2021-07-05T23:00:00","2021-07-06T23:00:00","2021-07-07T23:00:00","2021-07-08T23:00:00","2021-07-09T23:00:00","2021-07-10T23:00:00","2021-07-11T23:00:00","2021-07-12T23:00:00","2021-07-13T23:00:00","2021-07-14T23:00:00","2021-07-15T23:00:00","2021-07-16T23:00:00","2021-07-17T23:00:00","2021-07-18T23:00:00","2021-07-19T23:00:00","2021-07-20T23:00:00","2021-07-21T23:00:00","2021-07-22T23:00:00","2021-07-23T23:00:00","2021-07-24T23:00:00","2021-07-25T23:00:00","2021-07-26T23:00:00","2021-07-27T23:00:00","2021-07-28T23:00:00","2021-07-29T23:00:00","2021-07-30T23:00:00","2021-07-31T23:00:00","2021-08-01T23:00:00","2021-08-02T23:00:00","2021-08-03T23:00:00","2021-08-04T23:00:00","2021-08-05T23:00:00","2021-08-06T23:00:00","2021-08-07T23:00:00","2021-08-08T23:00:00","2021-08-09T23:00:00","2021-08-10T23:00:00","2021-08-11T23:00:00","2021-08-12T23:00:00","2021-08-13T23:00:00","2021-08-14T23:00:00","2021-08-15T23:00:00","2021-08-16T23:00:00","2021-08-17T23:00:00","2021-08-18T23:00:00","2021-08-19T23:00:00","2021-08-20T23:00:00","2021-08-21T23:00:00","2021-08-22T23:00:00","2021-08-23T23:00:00","2021-08-24T23:00:00","2021-08-25T23:00:00","2021-08-26T23:00:00","2021-08-27T23:00:00","2021-08-28T23:00:00","2021-08-29T23:00:00","2021-08-30T23:00:00","2021-08-31T23:00:00","2021-09-01T23:00:00","2021-09-02T23:00:00","2021-09-03T23:00:00","2021-09-04T23:00:00","2021-09-05T23:00:00","2021-09-06T23:00:00","2021-09-07T23:00:00","2021-09-08T23:00:00","2021-09-09T23:00:00","2021-09-10T23:00:00","2021-09-11T23:00:00","2021-09-12T23:00:00","2021-09-13T23:00:00","2021-09-14T23:00:00","2021-09-15T23:00:00","2021-09-16T23:00:00","2021-09-17T23:00:00","2021-09-18T23:00:00","2021-09-19T23:00:00","2021-09-20T23:00:00","2021-09-21T23:00:00","2021-09-22T23:00:00","2021-09-23T23:00:00","2021-09-24T23:00:00","2021-09-25T23:00:00","2021-09-26T23:00:00","2021-09-27T23:00:00","2021-09-28T23:00:00","2021-09-29T23:00:00","2021-09-30T23:00:00","2021-10-01T23:00:00","2021-10-02T23:00:0 ...

# %% [markdown]
# ## 6.   Model export

# %% [markdown]
# **H5** is a file format to store structured data, it's not a model by itself. Keras saves models in this format as it can easily store the weights and model configuration in a single file.

# %%
modelo.save('./outputs/h5/modelo.h5')

# %%
from IPython import display
display.Image("https://mcd.unison.mx/wp-content/themes/awaken/img/logo_mcd.png", embed = True)

# %% [markdown]
# <summary>
#     <font size="4" color="gray"> Maestría en Ciencia de Datos | Universidad de Sonora </font>
# </summary>
# <font size="1" color="gray"> Blvd. Luis Encinas y Rosales s/n Col. Centro. Edificio 3K1 planta baja C.P. 83000, Hermosillo, Sonora, México </font>
# <font size="1" color="gray"> mcd@unison.mx </font>
# <font size="1" color="gray"> Tel: +52 (662) 259 2155  </font>

# %% [markdown]
# ![spam](img/JB2.png)

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1.   Importing libraries and loading data

# %%
# Basic libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Normalization  libraries
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_percentage_error, r2_score

# Tensorflow with keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# Easy graphs with plotly
import plotly.express as px
import plotly.graph_objects as go

# Matplotlib plots look like
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (15,7)
import pickle as pk

import scipy
from scipy import stats

# %%
# Importing tensors
X_train = np.load('./outputs/split/X_train.npy')
X_val = np.load('./outputs/split/X_val.npy')
X_test = np.load('./outputs/split/X_test.npy')
y_train = np.load('./outputs/split/y_train.npy')
y_val = np.load('./outputs/split/y_val.npy')
y_test = np.load('./outputs/split/y_test.npy')

# %% [markdown]
# ## 2.   Setting the model

# %% [markdown]
# <summary>
#     <font size="4" color="orange"><b>1.1 Setting the parameters according to the tensors created in JNB1</b></font>
# </summary>

# %%
n_pasado = (24 * 7)+12
n_futuro = 24
n_salto = 12 

nom_attr = ['DEMANDA', 
            'MES', 
            'DIA', 
            'HORA',
            'PC1_CLIMA',
            'PC2_CLIMA',
            'LUNES_FESTIVO',
            'MARTES_POSTFESTIVO', 
            'SEMANA_SANTA', 
            '1_MAYO', 
            '10_MAYO', 
            '16_SEP',
            '2_NOV.', 
            'PRE-NAVIDAD_Y_NEW_YEAR', 
            'NAVIDAD_Y_NEW_YEAR',
            'POST-NAVIDAD_Y_NEW_YEAR' ]
n_attr = len(nom_attr)

# %% [markdown]
# <summary>
#     <font size="4" color="orange"><b>1.2 Configuring the LSTM Encoder-Decoder model</b></font>
# </summary>

# %% [markdown]
# MODEL
#
# <img src="img/encoders2_fig.png" alt="drawing" width="700"/>

# %% [markdown]
# LSTM UNIT
#
# <img src="img/lstm_unit.png" alt="drawing" width="400"/>
#
# Such that:
#
# * Forget Gate $F$: a NN with sigmoid
# * Candidate layer $C$: a NN with Tanh
# * Input Gate $I$: a NN with sigmoid
# * Output Gate $O$: a NN with sigmoid
# * Hidden state $h$: a vector, in our case we set $h\in\mathbb{R}^{100}$
# * Memory state $c$: a vector, in our case we set $c\in\mathbb{R}^{100}$

# %%
# Configuration of the encoder
encoder_inputs = layers.Input(shape=(n_pasado, n_attr))

encoder_l1 = layers.LSTM(100, return_state=True)# 100: dimension of hidden states
encoder_outputs1 = encoder_l1(encoder_inputs)

encoder_states1 = encoder_outputs1[1:]
# Out:
# Metal device set to: Apple M1 Max
# 2022-05-23 00:18:01.505471: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-05-23 00:18:01.505599: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
# Configuration of the encoder
decoder_rvec = layers.RepeatVector(n_futuro) # repeat vector 24 times
decoder_inputs = decoder_rvec(encoder_outputs1[0])

decoder_l1 = layers.LSTM(100, return_sequences=True)
decoder_l1_output = decoder_l1(decoder_inputs, initial_state=encoder_states1)

decoder_l2 = layers.TimeDistributed(layers.Dense(1)) # just one dense layer
decoder_outputs = decoder_l2(decoder_l1_output)

# %%
modelo = keras.models.Model(encoder_inputs, decoder_outputs)
modelo.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 180, 16)]    0           []
#
#  lstm (LSTM)                    [(None, 100),        46800       ['input_1[0][0]']
#                                  (None, 100),
#                                  (None, 100)]
#
#  repeat_vector (RepeatVector)   (None, 24, 100)      0           ['lstm[0][0]']
#
#  lstm_1 (LSTM)                  (None, 24, 100)      80400       ['repeat_vector[0][0]',
#                                                                   'lstm[0][1]',
#                                                                   'lstm[0][2]']
#
#  time_distributed (TimeDistribu  (None, 24, 1)       101         ['lstm_1[0][0]']
#  ted)
#
# ==================================================================================================
# Total params: 127,301
# Trainable params: 127,301
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## 3.   Training the model

# %% [markdown]
# Let $F_\theta: {\rm Mat}_{180\times 18}(\mathbb{R})\rightarrow \mathbb{R}^{24}$ be the nonlinear mapping given by the LSTM model where $\theta \in\mathbb{R}^{128,101}$ is the vector of parameters to fit
#
# The *training*, *validation* and *test* sets are codificated by the tensors $X_{180\times 18\times m}$ and $Y_{24\times 1\times m}$ for $m = m_{\rm train}, m_{\rm val}, m_{\rm test}$, as above. This tensors are, in each case,  just $m$ samples of the ordered pairs in ${\rm Mat}_{180\times 18}(\mathbb{R})\times \mathbb{R}^{24}$: $$\{(X^1,Y^1),(X^2,Y^2)
# \dots(X^m,Y^m)\}.$$
#
#
#
# <summary>
#     <font size="3" color="palevioletred"><b>Loss function</b></font>
# </summary>
#
# For fixed $\theta$ and tensor pair $X$ and $Y$, we set the **loss function** in terms of the MAE metric with the $\ell_1$ norm:
#
# $${\rm Loss}(X) = \frac{1}{m}\sum_{k=1}^m{\|F_\theta(X^k)-Y^k\|_1}$$
#
#
#
# <summary>
#     <font size="3" color="palevioletred"><b>Hyperparameters</b></font>
# </summary>
#
# * **epochs** (upper bound) = 25: An epoch is when an entire training set is passed  through the NN only once.
#
# * **batch size** = 32: Total number of training examples present in a single batch.
#
# * **patience** = 5:  Number of epochs with no improvement after which training will be stopped, in our case with respect to ${\rm Loss}(X_{\rm val})$.
#
# * **learning rate** $\alpha_{\rm epoch} = 1\times 10^{-3} \times 0.9 ^{\rm epoch}$
#
# <summary>
#     <font size="3" color="palevioletred"><b>Training process</b></font>
# </summary>

# %% [markdown]
# <img src="img/minibatch.png" alt="drawing" width="550"/>

# %%
## Sets the function for the rate learning in such a way that earning rate is smaller en each epoch
reduce_lr = keras.callbacks.LearningRateScheduler(lambda x: 1e-3 * 0.90 ** x) 

## During the run, the models of "best" result are stored according to "val_loss"

path_checkpoint = "./outputs/h5/model_checkpoint.h5"
modelckpt_callback = keras.callbacks.ModelCheckpoint(
    monitor="val_loss",
    filepath=path_checkpoint,
    verbose=1,
    save_weights_only=True,
    save_best_only=True,
)

## Setting the number of epochs with no improvement after which training will be stopped, 
## with respect to "val_loss". This is to avoid overfitting.
es_callback = keras.callbacks.EarlyStopping(
    monitor="val_loss", 
    min_delta=0, 
    patience=5 ### probar con menos
    
)

modelo.compile(
    optimizer=keras.optimizers.Adam(),  ### un tipo de descenso de gradiente más eficiente 'momento-inercia'
    loss="mae", ### determinación de la función de costo
    metrics=['accuracy']
)

history = modelo.fit(
    X_train,
    y_train,
    epochs=25,
    validation_data=(X_val,y_val),
    batch_size=32,
    callbacks=[reduce_lr, es_callback]
) ### guardar este history para graficar
# Out:
# Epoch 1/25
# 2022-05-23 00:18:03.886427: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-05-23 00:18:05.092473: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-23 00:18:05.297227: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-23 00:18:05.528903: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-23 00:18:05.615862: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-23 00:18:05.770821: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 3829/3829 [==============================] - ETA: 0s - loss: 0.0440 - accuracy: 1.9558e-04
# 2022-05-23 00:20:37.161640: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-23 00:20:37.235671: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-23 00:20:37.427842: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 3829/3829 [==============================] - 156s 40ms/step - loss: 0.0440 - accuracy: 1.9558e-04 - val_loss: 0.0213 - val_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 2/25
# 3829/3829 [==============================] - 153s 40ms/step - loss: 0.0312 - accuracy: 1.9592e-04 - val_loss: 0.0197 - val_accuracy: 0.0000e+00 - lr: 9.0000e-04
# Epoch 3/25
# 3829/3829 [==============================] - 156s 41ms/step - loss: 0.0284 - accuracy: 1.9592e-04 - val_loss: 0.0191 - val_accuracy: 0.0000e+00 - lr: 8.1000e-04
# Epoch 4/25
# 3829/3829 [==============================] - 159s 42ms/step - loss: 0.0269 - accuracy: 1.9592e-04 - val_loss: 0.0176 - val_accuracy: 0.0000e+00 - lr: 7.2900e-04
# Epoch 5/25
# 3829/3829 [==============================] - 162s 42ms/step - loss: 0.0258 - accuracy: 1.9592e-04 - val_loss: 0.0173 - val_accuracy: 0.0000e+00 - lr: 6.5610e-04
# Epoch 6/25
# 3829/3829 [==============================] - 163s 43ms/step - loss: 0.0251 - accuracy: 1.9592e-04 - val_loss: 0.0165 - val_accuracy: 0.0000e+00 - lr: 5.9049e-04
# Epoch 7/25
# 3829/3829 [==============================] - 163s 43ms/step - loss: 0.0243 - accuracy: 1.9592e-04 - val_loss: 0.0177 - val_accuracy: 0.0000e+00 - lr: 5.3144e-04
# Epoch 8/25
# 3829/3829 [==============================] - 163s 43ms/step - loss: 0.0236 - accuracy: 1.9592e-04 - val_loss: 0.0223 - val_accuracy: 0.0000e+00 - lr: 4.7830e-04
# Epoch 9/25
# 3829/3829 [==============================] - 165s 43ms/step - loss: 0.0228 - accuracy: 1.9592e-04 - val_loss: 0.0167 - val_accuracy: 0.0000e+00 - lr: 4.3047e-04
# Epoch 10/25
# 3829/3829 [==============================] - 165s 43ms/step - loss: 0.0221 - accuracy: 1.9592e-04 - val_loss: 0.0176 - val_accuracy: 0.0000e+00 - lr: 3.8742e-04
# Epoch 11/25
# 3829/3829 [==============================] - 163s 42ms/step - loss: 0.0214 - accuracy: 1.9592e-04 - val_loss: 0.0180 - val_accuracy: 0.0000e+00 - lr: 3.4868e-04

# %% [markdown]
# ## 4.   Model validation

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %%
# Model Loss Chart
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
## 5.   Model test results

# %%
df_test = pd.read_csv('./outputs/PCA/pca_exogenas_test.csv')
del df_test["Unnamed: 0"]

# %%
y_est = modelo.predict(X_test)
y_test[:,:,0].ravel().shape, y_est[:,:,0].ravel().shape, df_test['FECHA-HORA'][n_pasado + n_salto:].shape
# Out:
# 2022-05-23 00:47:31.624953: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-23 00:47:31.687907: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-23 00:47:31.883499: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# ((8568,), (8568,), (8568,))

# %%
scalers = pk.load(open("./outputs/DataProcessing/scalers.pkl",'rb'))

# %%
scaler = scalers['DEMANDA']
yr = scaler.inverse_transform(y_test[:,:,0].ravel().reshape(-1, 1))
yh = scaler.inverse_transform(y_est[:,:,0].ravel().reshape(-1, 1))

# %%
df_est = pd.DataFrame({
    "REAL": yr.ravel(),
    "ESTIMADO": yh.ravel(),
    "FECHA-HORA": df_test["FECHA-HORA"][n_pasado + n_salto:]     
})

# %%
df_est['FECHA-HORA']= pd.to_datetime(df_est['FECHA-HORA'])
df_est["HORA"] = df_est['FECHA-HORA'].dt.hour

# %%
real=[]
estimada =[]

df_est_result = pd.DataFrame(columns=['FECHA-HORA',"MAPE"])

for i, row in df_est.iterrows():

    n = row['HORA']
    
    real.append(row['REAL'])
    estimada.append(row['ESTIMADO'])
    
   
    if n == 23:
        df_est_result = df_est_result.append(pd.DataFrame({"FECHA-HORA": row['FECHA-HORA'],
                                           "MAPE": (mean_absolute_percentage_error(real, estimada))*100, 
                                           "R2": stats.pearsonr(real, estimada)[0]}, 
                                            index=[0]), ignore_index=True)
        n=0
        
        real=[]
        estimada =[]
    n+=1

# %%
df_est_result
# Out:
#               FECHA-HORA      MAPE        R2
# 0    2021-05-08 23:00:00   1.12694  0.988950
# 1    2021-05-09 23:00:00  1.635957  0.993761
# 2    2021-05-10 23:00:00    2.7314  0.993416
# 3    2021-05-11 23:00:00  4.304875  0.965107
# 4    2021-05-12 23:00:00  3.756905  0.987654
# ..                   ...       ...       ...
# 352  2022-04-25 23:00:00  2.073425  0.990041
# 353  2022-04-26 23:00:00  1.017303  0.990536
# 354  2022-04-27 23:00:00   0.94523  0.996165
# 355  2022-04-28 23:00:00  2.748051  0.997551
# 356  2022-04-29 23:00:00  2.118071  0.989995
#
# [357 rows x 3 columns]

# %%
df_est_result.to_csv('./outputs/Training_comparativos/corrida_original.csv')

# %% [markdown]
# ## Histogramas MAPES

# %%
fig = px.histogram(df_est_result, x="MAPE", nbins=12, title="Histograma MAPE Datos Originales")
fig.show()
# Out:
# <div>                            <div id="accd3791-a1ab-46a1-9039-490432a83c8f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("accd3791-a1ab-46a1-9039-490432a83c8f")) {                    Plotly.newPlot(                        "accd3791-a1ab-46a1-9039-490432a83c8f",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"MAPE=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":12,"offsetgroup":"","orientation":"v","showlegend":false,"x":[1.1269399368495838,1.635957325000292,2.731400115630257,4.304875096242932,3.7569048556423428,3.1935123534944916,3.15336318990824,1.867678212444407,2.3615333067183273,0.9284223102707067,0.8501706650566737,0.8438009391657474,0.7461254743661613,3.0642503382885637,0.9388634617808527,1.2843590373680718,1.3753038180693073,0.8443869071025061,2.2647376378703825,1.0782285805171714,1.6112862895504028,0.9353895494149784,0.876781034181311,1.4973085822666385,0.8395655238649569,1.5344321534596148,1.731974576907128,2.202175189660763,3.5031318005529597,1.0140476414368909,0.9549826311639462,0.8766299907725548,2.542768989957939,1.350253036542757,1.4693785190751647,1.4989214821858534,0.9598441492434535,0.847707686711389,1.5575165841729217,4.45761588404801,2.4283216065432325,2.1561525969300295,2.019263312570151,4.4357309574788975,2.3099750330822495,1.1333519914243517,1.0714365248075828,0.8829169373311719,1.0004155511671573,1.038556331625018,1.4028238828363364,2.6096045967721233,8.012294689440012,2.9632798370734332,3.590388373115089,0.953432912411783,3.4740519336644926,3.9873187246537776,2.521773176225643,3.158951465961468,2.157561405921933,1.5563911305490667,2.172276992155035,0.9928493571224944,3.562046992938319,4.1103369420107025,3.547194441977819,1.0349410364334977,1.6447004305776225,2.3514905963067183,2.5713180096494055,2.103305314669911,3.1924250139592547,3.2048593703751624,2.186439373260496,2.5209386261397615,1.9587406060837431,6.864885055250526,2.5481860831963745,4.1078737432977865,1.9043337541093779,1.8011454687008444,2.233063307154955,5.469428625719912,5.134252254268717,1.820083143324706,1.0581945090329452,1.9684542020757205,4.326580122495396,2.811501176689015,1.6605650705982073,2.6600201850067164,2.744931675489748,5.963475892952932,4.199363163782269,4.356723070433842,6.354858778914046,3.3542862244781952,1.1349009483693253,1.1478321859411973,6.226576743566611,1.116872989896009,2.011795765156614,1.2580887345571052,1.5580983674388995,3.7070761331965665,1.4438858158640553,5.145912089754012,5.3306203622585535,4.880736270827444,2.9668868617205617,4.3424009240601915,5.215026625926572,3.694793168948548,11.860735847021708,4.582474452491528,2.7669658763707696,1.3313529664448442,5.051800565658562,3.6591980549496492,3.886632338098938,3.381810112038313,0.7952504139274659,5.353128882274066,2.863342848758525,5.234496239618599,5.990274167849535,1.3673906204512416,2.4504642651111257,2.3434523715867854,2.139092437265593,5.129768403714565,1.4356748949543663,1.3002541085357817,1.8551206839575742,9.19221605333993,1.5844754726943762,2.5558998859379454,3.9695037188755258,6.269501978380419,3.2700746090841735,6.428574943016656,1.0868322408850077,1.2496648429435382,2.04219992259813,2.0934375204576474,0.806689684166053,4.168722479467024,1.2745075720244028,3.6262075414399355,1.135671655696298,2.535134076487657,1.5706544553680406,2.2813313940621636,1.1246530860363286,2.351939511848525,3.0611310264299325,7.363018482590963,9.411936771568447,5.560555381010504,2.0919730834221855,0.8964506369405891,0.9011926181865788,2.57893110703389,2.3697294564672458,5.110939832142098,2.380024109268628,2.012686122090907,3.0797536080313463,0.6420950576153835,0.952893924907245,2.3281874204113437,1.2035370759504214,0.903633182 ...

# %%
fig = px.histogram(df_est_result, x="R2", nbins=10, title="Histograma R2 Datos Originales")
fig.show()
# Out:
# <div>                            <div id="edc2601d-24e4-4db7-a930-b9cee8532179" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("edc2601d-24e4-4db7-a930-b9cee8532179")) {                    Plotly.newPlot(                        "edc2601d-24e4-4db7-a930-b9cee8532179",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"R2=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":10,"offsetgroup":"","orientation":"v","showlegend":false,"x":[0.9889501191402255,0.9937611486140342,0.9934164763507897,0.965106708183841,0.9876540688174518,0.9923465270873603,0.9971234725925928,0.9847962152217241,0.9954292915095283,0.9976453355780516,0.998572853108363,0.9984626804342934,0.9979399780021431,0.9759391482117806,0.9939095205311245,0.9912561286814275,0.9984297380269058,0.9995170204161665,0.9987261129796036,0.9977661377654435,0.9946825487408728,0.9989634648504542,0.9963967504388151,0.9948661558393279,0.995987217097199,0.9971678398227775,0.9963456007427653,0.9961597806052274,0.9941763952041566,0.995491369938652,0.9964730570434315,0.9960684501150006,0.992844114507889,0.9971717930293108,0.9954899199674226,0.9907970128500775,0.9948904875006024,0.9981481879337261,0.9982241195600206,0.9919428261772847,0.9957743661407044,0.9652057556224115,0.9795550141723104,0.861115413545907,0.986044535425981,0.9950248380583676,0.9949975956252559,0.9955986720957047,0.9902844581170306,0.9891733870577039,0.9869169066557567,0.9841780159208757,0.9429961153359894,0.9752980260455258,0.9715534285755557,0.9969857866440992,0.8595060019496328,0.8979644354791917,0.9712645154060608,0.9843968754793133,0.978087586799621,0.9882313507124987,0.9888546143828999,0.9940697916182095,0.9821400772530718,0.9877990085800515,0.9711874826459548,0.9964177619677674,0.9861411376544472,0.9892340598563546,0.9736348382862012,0.9917115371868919,0.9677937769402094,0.9662731107562506,0.9630427661506227,0.9769409861626319,0.9923495899702576,0.910801962858223,0.9870088530022232,0.952802082423425,0.9882740154491041,0.9836599754233932,0.9558439667782094,0.982386460546772,0.9762560192853477,0.980243586871808,0.9963101922780386,0.9594598847374075,0.9626245341737438,0.9879362142280539,0.9935915984683109,0.9897848925126965,0.9803303208796902,0.9948728105206218,0.9807070950138921,0.9937080500430333,0.837857523779295,0.9648946354563039,0.9913520140542718,0.9844304711517949,0.9957732107273924,0.9918386923818584,0.9940803271500216,0.997774649567319,0.9920217872294198,0.9733689865804975,0.9918146547076756,0.9800534359906101,0.9869483597804124,0.9835083533414645,0.923886510558448,0.9294874544261311,0.9636069982576184,0.9268690952047179,0.9117222693723123,0.9023488024906311,0.9973632522287644,0.9938443610741496,0.9598755259457714,0.917405331847154,0.9815106089571073,0.992765581719496,0.9968479868949894,0.9856300607371989,0.9954544826255641,0.9869260937781369,0.9544914400854284,0.9952550231361876,0.988220096174792,0.9925419833160226,0.981140142965622,0.9660419449177735,0.9885420800624667,0.992143029421531,0.9765610698428141,0.9937820564586524,0.9824233337937758,0.9934678803381025,0.9471780049479972,0.9673368798009315,0.9578402719022411,0.9858378063839766,0.9969291218079706,0.9978501650012406,0.9932185427016684,0.9980711971948029,0.9987426935698689,0.9796849777458723,0.9903198260058,0.9931452906842444,0.9957059802745682,0.99467650099342,0.9956292058874241,0.9903021656449662,0.9961109505256545,0.9832557792012466,0.9865104258605449,0.6069128541359162,0.7301377180331666,0.9922789810230765,0.988798855635795,0.998451881308964,0.9935437235255703,0.9892631368614219,0.9892920108115693,0.998295077185856,0.9920401615109818,0.9966871302398053,0.9942387967360068,0.9970676456568723,0.9956545404613415,0.9 ...

# %%
### Además de esto poner el histograma del df_est_result.MAPE y de df_est_result.R2

fig = px.line(df_est_result,x='FECHA-HORA', y='MAPE' ,title="MAPE Pronostico Redes Neuronales Encoders")
fig.show()
# Out:
# <div>                            <div id="70783a43-df2e-4e6f-9e28-d6e089afc6df" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("70783a43-df2e-4e6f-9e28-d6e089afc6df")) {                    Plotly.newPlot(                        "70783a43-df2e-4e6f-9e28-d6e089afc6df",                        [{"hovertemplate":"FECHA-HORA=%{x}<br>MAPE=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2021-05-08T23:00:00","2021-05-09T23:00:00","2021-05-10T23:00:00","2021-05-11T23:00:00","2021-05-12T23:00:00","2021-05-13T23:00:00","2021-05-14T23:00:00","2021-05-15T23:00:00","2021-05-16T23:00:00","2021-05-17T23:00:00","2021-05-18T23:00:00","2021-05-19T23:00:00","2021-05-20T23:00:00","2021-05-21T23:00:00","2021-05-22T23:00:00","2021-05-23T23:00:00","2021-05-24T23:00:00","2021-05-25T23:00:00","2021-05-26T23:00:00","2021-05-27T23:00:00","2021-05-28T23:00:00","2021-05-29T23:00:00","2021-05-30T23:00:00","2021-05-31T23:00:00","2021-06-01T23:00:00","2021-06-02T23:00:00","2021-06-03T23:00:00","2021-06-04T23:00:00","2021-06-05T23:00:00","2021-06-06T23:00:00","2021-06-07T23:00:00","2021-06-08T23:00:00","2021-06-09T23:00:00","2021-06-10T23:00:00","2021-06-11T23:00:00","2021-06-12T23:00:00","2021-06-13T23:00:00","2021-06-14T23:00:00","2021-06-15T23:00:00","2021-06-16T23:00:00","2021-06-17T23:00:00","2021-06-18T23:00:00","2021-06-19T23:00:00","2021-06-20T23:00:00","2021-06-21T23:00:00","2021-06-22T23:00:00","2021-06-23T23:00:00","2021-06-24T23:00:00","2021-06-25T23:00:00","2021-06-26T23:00:00","2021-06-27T23:00:00","2021-06-28T23:00:00","2021-06-29T23:00:00","2021-06-30T23:00:00","2021-07-01T23:00:00","2021-07-02T23:00:00","2021-07-03T23:00:00","2021-07-04T23:00:00","2021-07-05T23:00:00","2021-07-06T23:00:00","2021-07-07T23:00:00","2021-07-08T23:00:00","2021-07-09T23:00:00","2021-07-10T23:00:00","2021-07-11T23:00:00","2021-07-12T23:00:00","2021-07-13T23:00:00","2021-07-14T23:00:00","2021-07-15T23:00:00","2021-07-16T23:00:00","2021-07-17T23:00:00","2021-07-18T23:00:00","2021-07-19T23:00:00","2021-07-20T23:00:00","2021-07-21T23:00:00","2021-07-22T23:00:00","2021-07-23T23:00:00","2021-07-24T23:00:00","2021-07-25T23:00:00","2021-07-26T23:00:00","2021-07-27T23:00:00","2021-07-28T23:00:00","2021-07-29T23:00:00","2021-07-30T23:00:00","2021-07-31T23:00:00","2021-08-01T23:00:00","2021-08-02T23:00:00","2021-08-03T23:00:00","2021-08-04T23:00:00","2021-08-05T23:00:00","2021-08-06T23:00:00","2021-08-07T23:00:00","2021-08-08T23:00:00","2021-08-09T23:00:00","2021-08-10T23:00:00","2021-08-11T23:00:00","2021-08-12T23:00:00","2021-08-13T23:00:00","2021-08-14T23:00:00","2021-08-15T23:00:00","2021-08-16T23:00:00","2021-08-17T23:00:00","2021-08-18T23:00:00","2021-08-19T23:00:00","2021-08-20T23:00:00","2021-08-21T23:00:00","2021-08-22T23:00:00","2021-08-23T23:00:00","2021-08-24T23:00:00","2021-08-25T23:00:00","2021-08-26T23:00:00","2021-08-27T23:00:00","2021-08-28T23:00:00","2021-08-29T23:00:00","2021-08-30T23:00:00","2021-08-31T23:00:00","2021-09-01T23:00:00","2021-09-02T23:00:00","2021-09-03T23:00:00","2021-09-04T23:00:00","2021-09-05T23:00:00","2021-09-06T23:00:00","2021-09-07T23:00:00","2021-09-08T23:00:00","2021-09-09T23:00:00","2021-09-10T23:00:00","2021-09-11T23:00:00","2021-09-12T23:00:00","2021-09-13T23:00:00","2021-09-14T23:00:00","2021-09-15T23:00:00","2021-09-16T23:00:00","2021-09-17T23:00:00","2021-09-18T23:00:00","2021-09-19T23:00:00","2021-09-20T23:00:00","2021-09-21T23:00:00","2021-09-22T23:00:00","2021-09-23T23:00:00","2021-09-24T23:00:00","2021-09-25T23:00:00","2021-09-26T23:00:00","2021-09-27T23:00:00","2021-09-28T23:00:00","2021-09-29T23:00:00","2021-09-30T23:00:00","2021-10-01T23:00:00","2021-10-02T23:00 ...

# %%
fig = px.line(df_est_result,x='FECHA-HORA', y='R2' ,title="R2 Score Pronostico Redes Neuronales Encoders")
fig.show()
# Out:
# <div>                            <div id="d540cca8-091e-42e8-b53f-611d2c31f140" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d540cca8-091e-42e8-b53f-611d2c31f140")) {                    Plotly.newPlot(                        "d540cca8-091e-42e8-b53f-611d2c31f140",                        [{"hovertemplate":"FECHA-HORA=%{x}<br>R2=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2021-05-08T23:00:00","2021-05-09T23:00:00","2021-05-10T23:00:00","2021-05-11T23:00:00","2021-05-12T23:00:00","2021-05-13T23:00:00","2021-05-14T23:00:00","2021-05-15T23:00:00","2021-05-16T23:00:00","2021-05-17T23:00:00","2021-05-18T23:00:00","2021-05-19T23:00:00","2021-05-20T23:00:00","2021-05-21T23:00:00","2021-05-22T23:00:00","2021-05-23T23:00:00","2021-05-24T23:00:00","2021-05-25T23:00:00","2021-05-26T23:00:00","2021-05-27T23:00:00","2021-05-28T23:00:00","2021-05-29T23:00:00","2021-05-30T23:00:00","2021-05-31T23:00:00","2021-06-01T23:00:00","2021-06-02T23:00:00","2021-06-03T23:00:00","2021-06-04T23:00:00","2021-06-05T23:00:00","2021-06-06T23:00:00","2021-06-07T23:00:00","2021-06-08T23:00:00","2021-06-09T23:00:00","2021-06-10T23:00:00","2021-06-11T23:00:00","2021-06-12T23:00:00","2021-06-13T23:00:00","2021-06-14T23:00:00","2021-06-15T23:00:00","2021-06-16T23:00:00","2021-06-17T23:00:00","2021-06-18T23:00:00","2021-06-19T23:00:00","2021-06-20T23:00:00","2021-06-21T23:00:00","2021-06-22T23:00:00","2021-06-23T23:00:00","2021-06-24T23:00:00","2021-06-25T23:00:00","2021-06-26T23:00:00","2021-06-27T23:00:00","2021-06-28T23:00:00","2021-06-29T23:00:00","2021-06-30T23:00:00","2021-07-01T23:00:00","2021-07-02T23:00:00","2021-07-03T23:00:00","2021-07-04T23:00:00","2021-07-05T23:00:00","2021-07-06T23:00:00","2021-07-07T23:00:00","2021-07-08T23:00:00","2021-07-09T23:00:00","2021-07-10T23:00:00","2021-07-11T23:00:00","2021-07-12T23:00:00","2021-07-13T23:00:00","2021-07-14T23:00:00","2021-07-15T23:00:00","2021-07-16T23:00:00","2021-07-17T23:00:00","2021-07-18T23:00:00","2021-07-19T23:00:00","2021-07-20T23:00:00","2021-07-21T23:00:00","2021-07-22T23:00:00","2021-07-23T23:00:00","2021-07-24T23:00:00","2021-07-25T23:00:00","2021-07-26T23:00:00","2021-07-27T23:00:00","2021-07-28T23:00:00","2021-07-29T23:00:00","2021-07-30T23:00:00","2021-07-31T23:00:00","2021-08-01T23:00:00","2021-08-02T23:00:00","2021-08-03T23:00:00","2021-08-04T23:00:00","2021-08-05T23:00:00","2021-08-06T23:00:00","2021-08-07T23:00:00","2021-08-08T23:00:00","2021-08-09T23:00:00","2021-08-10T23:00:00","2021-08-11T23:00:00","2021-08-12T23:00:00","2021-08-13T23:00:00","2021-08-14T23:00:00","2021-08-15T23:00:00","2021-08-16T23:00:00","2021-08-17T23:00:00","2021-08-18T23:00:00","2021-08-19T23:00:00","2021-08-20T23:00:00","2021-08-21T23:00:00","2021-08-22T23:00:00","2021-08-23T23:00:00","2021-08-24T23:00:00","2021-08-25T23:00:00","2021-08-26T23:00:00","2021-08-27T23:00:00","2021-08-28T23:00:00","2021-08-29T23:00:00","2021-08-30T23:00:00","2021-08-31T23:00:00","2021-09-01T23:00:00","2021-09-02T23:00:00","2021-09-03T23:00:00","2021-09-04T23:00:00","2021-09-05T23:00:00","2021-09-06T23:00:00","2021-09-07T23:00:00","2021-09-08T23:00:00","2021-09-09T23:00:00","2021-09-10T23:00:00","2021-09-11T23:00:00","2021-09-12T23:00:00","2021-09-13T23:00:00","2021-09-14T23:00:00","2021-09-15T23:00:00","2021-09-16T23:00:00","2021-09-17T23:00:00","2021-09-18T23:00:00","2021-09-19T23:00:00","2021-09-20T23:00:00","2021-09-21T23:00:00","2021-09-22T23:00:00","2021-09-23T23:00:00","2021-09-24T23:00:00","2021-09-25T23:00:00","2021-09-26T23:00:00","2021-09-27T23:00:00","2021-09-28T23:00:00","2021-09-29T23:00:00","2021-09-30T23:00:00","2021-10-01T23:00:00","2021-10-02T23:00:0 ...

# %% [markdown]
# ## 6.   Model export

# %% [markdown]
# **H5** is a file format to store structured data, it's not a model by itself. Keras saves models in this format as it can easily store the weights and model configuration in a single file.

# %%
modelo.save('./outputs/h5/modelo.h5')

# %%
from IPython import display
display.Image("https://mcd.unison.mx/wp-content/themes/awaken/img/logo_mcd.png", embed = True)

# %% [markdown]
# <summary>
#     <font size="4" color="gray"> Maestría en Ciencia de Datos | Universidad de Sonora </font>
# </summary>
# <font size="1" color="gray"> Blvd. Luis Encinas y Rosales s/n Col. Centro. Edificio 3K1 planta baja C.P. 83000, Hermosillo, Sonora, México </font>
# <font size="1" color="gray"> mcd@unison.mx </font>
# <font size="1" color="gray"> Tel: +52 (662) 259 2155  </font>
